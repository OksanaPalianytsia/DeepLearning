# %%
#!pip install --user --upgrade pip
#!pip install -U setuptools --user
# !pip install mlflow
#!pip install pandas
#!pip install numpy
#!pip install seaborn
#!pip install sklearn
#!pip install matplotlib
#!pip install pycaret
#!pip install ipywidgets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 25.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 18.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.6/230.6 kB 23.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 16.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.8 MB/s eta 0:00:00
# ...

# %%
#!pip3 uninstall lightgbm -y
#!pip install lightgbm --config-settings=cmake.define.USE_GPU=ON
# install pycaret
# !pip install --upgrade pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.7/484.7 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 22.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 44.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 27.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 37.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.2 MB/s eta 0:00:00
# ...

# %%
#uninstall lightgbm CPU
# !pip uninstall lightgbm -y

# install lightgbm GPU
#!pip install lightgbm --install-option=--gpu
# !pip install lightgbm --config-settings=cmake.define.USE_GPU=ON
# Out:
# Found existing installation: lightgbm 4.1.0
# Uninstalling lightgbm-4.1.0:
#   Successfully uninstalled lightgbm-4.1.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 13.0 MB/s eta 0:00:00
# ...

# %%
import mlflow
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

from pycaret.classification import *

from sklearn.datasets import fetch_20newsgroups
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
mlflow.autolog()
# Out:
# 2023/12/14 00:06:11 WARNING mlflow.tracking.fluent: Exception raised while enabling autologging for statsmodels: cannot import name 'prod' from 'scipy._lib._util' (/usr/local/lib/python3.10/dist-packages/scipy/_lib/_util.py)
# Exception ignored on calling ctypes callback function: <function ThreadpoolController._find_libraries_with_dl_iterate_phdr.<locals>.match_library_callback at 0x79f075381d80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/threadpoolctl.py", line 847, in match_library_callback
#     self._make_controller_from_path(filepath)
#   File "/usr/local/lib/python3.10/dist-packages/threadpoolctl.py", line 984, in _make_controller_from_path
#     lib_controller = controller_class(filepath=filepath, prefix=prefix)
#   File "/usr/local/lib/python3.10/dist-packages/threadpoolctl.py", line 111, in __init__
#     self.dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
# ...

# %%
def load_dataset():
    #завантажуємо датасет 20newsgroupdataset для тестування і тренування разомб ігноруючи перелічені стовпці
    return fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'), shuffle = True)

# %%
def split_dataset(data_frame, testsize):
    # формуємо тестовий та тренувальний датасети
    train, test = train_test_split(data_frame, test_size = testsize)
    text_data = data_frame.keys()[0]
    class_target = data_frame.keys()[1]
    x_train, y_train = train.text_data, train.class_target
    x_test, y_test = test.text_data, test.class_target
    return x_train, y_train, x_test, y_test

# %%
def tf_idf(x_train, x_test):
    # створюємо об'єкт для подальшого перетворення текстових тренувальних та тестових даних у матриці tf_idf
    # викидаємо стоп-слова (англійської мови)
    # застос. tf масштабування: замінюємо tf на 1 + log(tf)
    vectorizer = TfidfVectorizer(stop_words = "english", max_df = 0.5, sublinear_tf = True)
    x_train = vectorizer.fit_transform(x_train)
    # зберігаємо дані нормалізації з fit_transform(X_train) і застосовуємо дол тестових даних
    x_test = vectorizer.transform(x_test)
    features = vectorizer.get_feature_names_out()
    # повертаємо перелік слів-feature (стовпців в отриманих таблицях) для тренувальних та тестових даних
    return x_train, x_test, features

# %%
news_groups = load_dataset()

# %%
dataframe = pd.DataFrame({'text_data':news_groups.data, 'class_target': news_groups.target})

# %%
dataframe
# Out:
#                                                text_data  class_target
# 0      I was wondering if anyone out there could enli...             7
# 1      A fair number of brave souls who upgraded thei...             4
# 2      well folks, my mac plus finally gave up the gh...             4
# 3      \nDo you have Weitek's address/phone number?  ...             1
# 4      From article <C5owCB.n3p@world.std.com>, by to...            14
# ...                                                  ...           ...
# 11309  DN> From: nyeda@cnsvax.uwec.edu (David Nye)\nD...            13
# 11310  I have a (very old) Mac 512k and a Mac Plus, b...             4
# 11311  I just installed a DX2-66 CPU in a clone mothe...             3
# 11312  \nWouldn't this require a hyper-sphere.  In 3-...             1
# 11313  Stolen from Pasadena between 4:30 and 6:30 pm ...             8
#
# [11314 rows x 2 columns]

# %%
X_train, y_train, X_test, y_test = split_dataset(dataframe, 0.15)

# %%
X_train, X_test, words = tf_idf(X_train, X_test)
print(X_train.shape)
print(X_test.shape)
print(words.shape)
# Out:
# (9616, 92306)
# (1698, 92306)
# (92306,)

# %%
experiment = setup(data = X_train, target = y_train.values, log_experiment = True, experiment_name = 'class_of_text_prediction', use_gpu = True)
# Out:
# 2023/12/14 00:08:29 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3aa3ba1f81624d698237a1fc8f6770bf', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current lightgbm workflow
# 2023/12/14 00:08:29 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'a0d4d5ef06204354ab791499448d7a0a', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current lightgbm workflow
# 2023/12/14 00:08:29 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c3e470fb16f44c0e8f98c17a2839b2f0', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current lightgbm workflow
# ...

# %%
best_model = experiment.compare_models(turbo=True)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      00:28:44
# Status     . . . . . . . . . . . . . . . . . .              Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Classifier
# <style type="text/css">
# #T_2e6f2 th {
#   text-align: left;
# }
# ...

# %%
experiment.evaluate_model(best_model)

# %%
plot_model(best_model, plot = 'confusion_matrix')

# %%
plot_model(best_model, plot = 'feature')

# %%
plot_model(best_model, plot = 'pr')

# %%
plot_model(best_model, plot = 'class_report')

# %%
plot_model(best_model, plot = 'error')

# %%
plot_model(best_model, plot = 'learning')

# %% [markdown]
# Test data

# %%
y_predicted = best_model.predict(X_test)
accuracy_score(y_test.values, y_predicted)
# Out:
# 0.7400530503978779

# %%
conf_matrix = confusion_matrix(y_test.values, y_predicted)
class_names = news_groups['target_names']

plt.figure(figsize = (10,10))
svm = sns.heatmap(conf_matrix, annot = True, xticklabels = class_names, yticklabels = class_names, fmt='g')
plt.ylabel('predicted', fontsize = 12)
plt.xlabel('actual', fontsize = 12)
# Out:
# Text(0.5, 58.7222222222222, 'Actual')

# %%
report = classification_report(y_test.values, y_predicted)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.60      0.64       166
#            1       0.76      0.75      0.76       195
#            2       0.74      0.79      0.77       190
#            3       0.69      0.63      0.66       192
#            4       0.79      0.74      0.76       222
#            5       0.84      0.86      0.85       207
#            6       0.71      0.71      0.71       204
#            7       0.55      0.80      0.65       208
#            8       0.80      0.73      0.77       194
#            9       0.87      0.84      0.85       192
#           10       0.92      0.87      0.89       194
#           11       0.84      0.76      0.80       198
#           12       0.71      0.70      0.71       203
#           13       0.80      0.78      0.79       190
#           14       0.83      0.76      0.79       198
#           15       0.64      0.79      0.71       173
# ...
